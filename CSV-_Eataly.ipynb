# %%
#Import Pandas
import pandas as pd

#load in from CSV
df = pd.read_csv('Dec15-21_Eataly_Schedule.csv')

# %%
#drop all irrelevant rows at the top
df = df.drop([0,2,3,4])

#reset indexes
df = df.reset_index(drop=True)

# %%
#rename the column names:
df = df.rename(columns={'Unnamed: 0':'Name'})

df = df.rename(columns={'Monday':'Monday_AM'})
df = df.rename(columns={'Unnamed: 2':'Monday_PM'})

df = df.rename(columns={'Tuesday':'Tuesday_AM'})
df = df.rename(columns={'Unnamed: 4':'Tuesday_PM'})

df = df.rename(columns={'Wednesday':'Wednesday_AM'})
df = df.rename(columns={'Unnamed: 6':'Wednesday_PM'})

df = df.rename(columns={'Thursday':'Thursday_AM'})
df = df.rename(columns={'Unnamed: 8':'Thursday_PM'})

df = df.rename(columns={'Friday':'Friday_AM'})
df = df.rename(columns={'Unnamed: 10':'Friday_PM'})

df = df.rename(columns={'Saturday':'Saturday_AM'})
df = df.rename(columns={'Unnamed: 12':'Saturday_PM'})

df = df.rename(columns={'Sunday':'Sunday_AM'})
df = df.rename(columns={'Unnamed: 14':'Sunday_PM'})

# %%
#Clean up events row by replacing empty cells with 'none'
df.iloc[0] = df.iloc[0].fillna("None")

#extract events as a list
first_row_list = df.iloc[0].tolist()

first_row_list
# Out:
# ['EVENTS',
#  '14pax a la carte MDR 1pm-3pm, 13pax MDR a la carte 530pm-730pm',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  '26pax MDR family style 4pm-630pm, 15pax PDR family style 5pm-730pm',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None']

# %%
#remove events row
df = df.drop(0)

#reset indexes
df = df.reset_index(drop=True)

#replace all empty cells with 'OFF'
df = df.fillna('OFF')
df
# Out:
#                   Name Monday_AM Monday_PM Tuesday_AM Tuesday_PM Wednesday_AM  \
# 0        Mudasir Addow    1015AM       OFF     1015AM        OFF       1015AM
# 1    Ilia Belchevichen       OFF       OFF     1015AM        OFF       1015AM
# 2   Alejandra Calderon       SET       SET        SET        SET        11:00
# 3       Jaikaran Chugh       SET     415PM        SET      415PM          SET
# 4      Diletta Di Toma       OFF       OFF        OFF      415PM        14:00
# 5          Diana Duong       SET       SET        SET        SET          SET
# 6       Daniel Herrera       REQ       SET        SET        OFF          SET
# 7       David Morillas       OFF     415PM        OFF      415PM          OFF
# 8        Akriti Kandel       OFF     415PM        OFF        OFF          OFF
# 9        Kiana Mercado       OFF     415PM        OFF        OFF          OFF
# 10       Hasaan Mohsin       OFF     415PM     1015AM        OFF       1015AM
# 11       Tibor Lorincz    1015AM       OFF     1015AM        OFF       1015AM
# 12       Arafa Mutimba    1015AM       OFF     1015AM        OFF          OFF
# 13        Alessia Moro       OFF       OFF        OFF        OFF        11:00
# 14       Falguni Patel       OFF     415PM        OFF      415PM          OFF
# 15        Jude Salcedo       OFF     415PM        OFF      415PM          OFF
# 16          Mac Sealby       SET       REQ        SET        REQ          SET
# 17            Tiger Wu       OFF       OFF        OFF        OFF       1015AM
# 18           Esma Sari    1015AM       OFF      14:00        OFF       1015AM
# 19         Sahil Thapa     14:00       OFF        OFF      415PM          OFF
# 20      Sabrina Santos       OFF     415PM     1015AM        OFF       1015AM
# 21    Julaiti Xijaaiti       OFF       OFF     1015AM        OFF       1015AM
# 22     Adrio Fattorini    1015AM       OFF     1015AM        OFF          OFF
# 23         Hailey Jang       SET       REQ        SET        REQ          SET
# 24     Maria Giugliano    1015AM       OFF        OFF        OFF        11:00
# 25    Grivia Fernandes       SET       OFF        SET      530PM        11:00
# 26       Joshua Kaanoi    1015AM       OFF        SET      415PM        11:00
# 27      Ugurcan Kesman       SET       SET        SET        SET        11:00
# 28    Franco Dagostino    1015AM       OFF        OFF      415PM        11:00
# 29          Chloe Hand       OFF     415PM        OFF        OFF        11:00
#
#    Wednesday_PM Thursday_AM  Thursday_PM Friday_AM Friday_PM Saturday_AM  \
# 0           OFF      1015AM          OFF    1015AM       OFF         SET
# 1           OFF      1015AM          OFF       OFF     415PM         OFF
# 2           SET         SET        415PM       OFF     415PM         OFF
# 3         415PM         SET        415PM       SET     415PM         OFF
# 4           OFF      1015AM          OFF    1015AM       OFF      1015AM
# 5           SET         SET          SET       SET       SET         SET
# 6         415PM         SET        415PM    1015AM       SET      1015AM
# 7           OFF         OFF          OFF    1015AM       OFF      1015AM
# 8           OFF         OFF  430PM EVENT       OFF     415PM         OFF
# 9           OFF         OFF        415PM       OFF     415PM         OFF
# 10          OFF         OFF          OFF       OFF     415PM         OFF
# 11          OFF         OFF          OFF       OFF     415PM         OFF
# 12          OFF         OFF          OFF    1015AM       OFF      1015AM
# 13        415PM         OFF        415PM       OFF     415PM       14:00
# 14          OFF         OFF        415PM     14:00       OFF         OFF
# 15          OFF       14:00          OFF       OFF     415PM         OFF
# 16          REQ         SET          SET       REQ       REQ         REQ
# 17          OFF      1015AM          OFF    1015AM       OFF      1015AM
# 18          OFF         OFF        415PM       OFF       OFF      1015AM
# 19          OFF         OFF          OFF    1015AM       OFF      1015AM
# 20          OFF      1015AM          OFF       OFF       OFF         OFF
# 21          OFF      1015AM          OFF       OFF       SET      1015AM
# 22          OFF      1015AM          OFF       OFF     415PM         OFF
# 23          REQ         SET          REQ       SET       REQ         SET
# 24        415PM      1015AM          OFF    1015AM       OFF         OFF
# 25        530PM         SET        530PM       SET       OFF         SET
# 26        415PM         SET        415PM       OFF       OFF      1015AM
# 27        415PM         OFF        415PM       OFF     415PM      1015AM
# 28        415PM         OFF          OFF    1015AM       OFF         OFF
# 29        415PM         OFF          OFF    1015AM       OFF       14:00
#
#       Saturday_PM Sunday_AM      Sunday_PM
# 0             SET       SET            SET
# 1             OFF    1015AM            OFF
# 2           415PM       SET            SET
# 3             OFF       OFF            OFF
# 4             OFF       OFF            OFF
# 5             SET    1015AM  415PM 1st cut
# 6             SET       SET          415PM
# 7             OFF    1015AM            OFF
# 8           415PM       OFF          415PM
# 9           415PM       OFF          415PM
# 10          415PM       OFF            OFF
# 11          415PM       OFF            OFF
# 12  415PM 1st cut       OFF          415PM
# 13            OFF    1015AM            REQ
# 14          415PM       OFF            OFF
# 15          415PM       OFF            OFF
# 16            REQ       REQ            REQ
# 17            OFF    1015AM            OFF
# 18            OFF       OFF            OFF
# 19            OFF    1015AM            OFF
# 20            OFF    1015AM            OFF
# 21            SET    1015AM            SET
# 22            OFF    1015AM            OFF
# 23          415PM       SET          415PM
# 24            OFF    1015AM            OFF
# 25          415PM       OFF          415PM
# 26            OFF       SET            OFF
# 27            OFF       OFF          415PM
# 28            OFF     14:00            OFF
# 29            OFF     14:00            OFF

# %%
df.to_csv('EXTRACT1')

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_abbrev = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# Function to clean and format time values
def format_time(val):
    val = str(val).strip()
    if val in ['OFF', 'SET', 'REQ', 'nan', '']:
        return val
    return val

# Build schedule data
schedule_data = []

for _, row in df.iterrows():
    name = row['Name']
    person_schedule = {'name': name}
    
    for day, abbrev in zip(days, day_abbrev):
        am_col = f'{day}_AM'
        pm_col = f'{day}_PM'
        
        am_val = str(row[am_col]).strip()
        pm_val = str(row[pm_col]).strip()
        
        # Collect actual shift times
        shifts = []
        
        if am_val not in ['OFF', 'SET', 'nan', '']:
            shifts.append(format_time(am_val))
        
        if pm_val not in ['OFF', 'SET', 'nan', '']:
            shifts.append(format_time(pm_val))
        
        # Determine shift status based on priority rules
        if shifts:
            # If either has a time, show the time(s)
            if len(shifts) == 1:
                person_schedule[abbrev] = shifts[0]
            else:
                person_schedule[abbrev] = shifts
        elif am_val == 'SET' and pm_val == 'SET':
            person_schedule[abbrev] = 'SET'
        elif am_val == 'OFF' and pm_val == 'SET':
            person_schedule[abbrev] = 'OFF'
        elif am_val == 'SET' and pm_val == 'OFF':
            person_schedule[abbrev] = 'OFF'
        else:
            person_schedule[abbrev] = 'OFF'
    
    schedule_data.append(person_schedule)

# %%
js_code = "const scheduleData = [\n"

for i, person in enumerate(schedule_data):
    js_code += "    { "
    items = []
    for key, value in person.items():
        if key == 'name':
            items.append(f'name: "{value}"')
        else:
            if isinstance(value, list):
                # Format array of shifts
                formatted_shifts = ', '.join([f'"{shift}"' for shift in value])
                items.append(f'{key}: [{formatted_shifts}]')
            else:
                items.append(f'{key}: "{value}"')
    
    js_code += ", ".join(items)
    
    if i < len(schedule_data) - 1:
        js_code += " },\n"
    else:
        js_code += " }\n"

js_code += "];"

# Save to file
with open('schedule_data.js', 'w') as f:
    f.write(js_code)

print("Schedule data saved to 'schedule_data.js'")
print(js_code)
# Out:
# Schedule data saved to 'schedule_data.js'
# const scheduleData = [
#     { name: "Mudasir Addow", Mon: "1015AM", Tue: "1015AM", Wed: "1015AM", Thu: "1015AM", Fri: "1015AM", Sat: "SET", Sun: "SET" },
#     { name: "Ilia Belchevichen", Mon: "OFF", Tue: "1015AM", Wed: "1015AM", Thu: "1015AM", Fri: "415PM", Sat: "OFF", Sun: "1015AM" },
#     { name: "Alejandra Calderon", Mon: "SET", Tue: "SET", Wed: "11:00", Thu: "415PM", Fri: "415PM", Sat: "415PM", Sun: "SET" },
#     { name: "Jaikaran Chugh", Mon: "415PM", Tue: "415PM", Wed: "415PM", Thu: "415PM", Fri: "415PM", Sat: "OFF", Sun: "OFF" },
#     { name: "Diletta Di Toma", Mon: "OFF", Tue: "415PM", Wed: "14:00", Thu: "1015AM", Fri: "1015AM", Sat: "1015AM", Sun: "OFF" },
#     { name: "Diana Duong", Mon: "SET", Tue: "SET", Wed: "SET", Thu: "SET", Fri: "SET", Sat: "SET", Sun: ["1015AM", "415PM 1st cut"] },
#     { name: "Daniel Herrera", Mon: "REQ", Tue: "OFF", Wed: "415PM", Thu: "415PM", Fri: "1015AM", Sat: "1015AM", Sun: "415PM" },
#     { name: "David Morillas", Mon: "415PM", Tue: "415PM", Wed: "OFF", Thu: "OFF", Fri: "1015AM", Sat: "1015AM", Sun: "1015AM" },
#     { name: "Akriti Kandel", Mon: "415PM", Tue: "OFF", Wed: "OFF", Thu: "430PM EVENT", Fri: "415PM", Sat: "415PM", Sun: "415PM" },
#     { name: "Kiana Mercado", Mon: "415PM", Tue: "OFF", Wed: "OFF", Thu: "415PM", Fri: "415PM", Sat: "415PM", Sun: "415PM" },
#     { name: "Hasaan Mohsin", Mon: "415PM", Tue: "1015AM", Wed: "1015AM", Thu: "OFF", Fri: "415PM", Sat: "415PM", Sun: "OFF" },
#     { name: "Tibor Lorincz", Mon: "1015AM", Tue: "1015AM", Wed: "1015AM", Thu: "OFF", Fri: "415PM", Sat: "415PM", Sun: "OFF" },
#     { name: "Arafa Mutimba", Mon: "1015AM", Tue: "1015AM", Wed: "OFF", Thu: "OFF", Fri: "1015AM", Sat: ["1015AM", "415PM 1st cut"], Sun: "415PM" },
#     { name: "Alessia Moro", Mon: "OFF", Tue: "OFF", Wed: ["11:00", "415PM"], Thu: "415PM", Fri: "415PM", Sat: "14:00", Sun: ["1015AM", "REQ"] },
#     { name: "Falguni Patel", Mon: "415PM", Tue: "415PM", Wed: "OFF", Thu: "415PM", Fri: "14:00", Sat: "415PM", Sun: "OFF" },
#     { name: "Jude Salcedo", Mon: "415PM", Tue: "415PM", Wed: "OFF", Thu: "14:00", Fri: "415PM", Sat: "415PM", Sun: "OFF" },
#     { name: "Mac Sealby", Mon: "REQ", Tue: "REQ", Wed: "REQ", Thu: "SET", Fri: ["REQ", "REQ"], Sat: ["REQ", "REQ"], Sun: ["REQ", "REQ"] },
#     { name: "Tiger Wu", Mon: "OFF", Tue: "OFF", Wed: "1015AM", Thu: "1015AM", Fri: "1015AM", Sat: "1015AM", Sun: "1015AM" },
#     { name: "Esma Sari", Mon: "1015AM", Tue: "14:00", Wed: "1015AM", Thu: "415PM", Fri: "OFF", Sat: "1015AM", Sun: "OFF" },
#     { name: "Sahil Thapa", Mon: "14:00", Tue: "415PM", Wed: "OFF", Thu: "OFF", Fri: "1015AM", Sat: "1015AM", Sun: "1015AM" },
#     { name: "Sabrina Santos", Mon: "415PM", Tue: "1015AM", Wed: "1015AM", Thu: "1015AM", Fri: "OFF", Sat: "OFF", Sun: "1015AM" },
#     { name: "Julaiti Xijaaiti", Mon: "OFF", Tue: "1015AM", Wed: "1015AM", Thu: "1015AM", Fri: "OFF", Sat: "1015AM", Sun: "1015AM" },
#     { name: "Adrio Fattorini", Mon: "1015AM", Tue: "1015AM", Wed: "OFF", Thu: "1015AM", Fri: "415PM", Sat: "OFF", Sun: "1015AM" },
#     { name: "Hailey Jang", Mon: "REQ", Tue: "REQ", Wed: "REQ", Thu: "REQ", Fri: "REQ", Sat: "415PM", Sun: "415PM" },
#     { name: "Maria Giugliano", Mon: "1015AM", Tue: "OFF", Wed: ["11:00", "415PM"], Thu: "1015AM", Fri: "1015AM", Sat: "OFF", Sun: "1015AM" },
#     { name: "Grivia Fernandes", Mon: "OFF", Tue: "530PM", Wed: ["11:00", "530PM"], Thu: "530PM", Fri: "OFF", Sat: "415PM", Sun: "415PM" },
#     { name: "Joshua Kaanoi", Mon: "1015AM", Tue: "415PM", Wed: ["11:00", "415PM"], Thu: "415PM", Fri: "OFF", Sat: "1015AM", Sun: "OFF" },
#     { name: "Ugurcan Kesman", Mon: "SET", Tue: "SET", Wed: ["11:00", "415PM"], Thu: "415PM", Fri: "415PM", Sat: "1015AM", Sun: "415PM" },
#     { name: "Franco Dagostino", Mon: "1015AM", Tue: "415PM", Wed: ["11:00", "415PM"], Thu: "OFF", Fri: "1015AM", Sat: "OFF", Sun: "14:00" },
#     { name: "Chloe Hand", Mon: "415PM", Tue: "OFF", Wed: ["11:00", "415PM"], Thu: "OFF", Fri: "1015AM", Sat: "14:00", Sun: "14:00" }
# ];
